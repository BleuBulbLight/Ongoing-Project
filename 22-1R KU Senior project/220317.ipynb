# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel("C:/GitRepo/Ongoing-Project/22-1R KU Senior project/2022년 1월 서울시 차량통행속도 (Hyun).xlsx")

df
# Out:
#               일자 요일      도로명       링크아이디            시점명      종점명  방향    거리  \
# 0       20220128  금      을지로  1010011500    동대문역사문화공원입구    한양공고앞  상행   152
# 1       20220106  목  가산디지털1로  1170004100       한국산업기술협회   금천고가차도  상행   392
# 2       20220127  목  가산디지털1로  1170004100       한국산업기술협회   금천고가차도  상행   392
# 3       20220125  화  가산디지털1로  1170004100       한국산업기술협회   금천고가차도  상행   392
# 4       20220121  금      안암로  1070003400          안암오거리   고대앞사거리  상행   507
# ...          ... ..      ...         ...            ...      ...  ..   ...
# 156614  20220128  금   경인고속도로  1140022200           신월IC  화곡고가사거리  상행   961
# 156615  20220128  금   경인고속도로  1140040500        화곡고가사거리     신월IC  하행   961
# 156616  20220129  토   경부고속도로  2040002902  경부고속도로(만남의광장)    달래네고개  상행  2716
# 156617  20220130  일   경부고속도로  2040002902  경부고속도로(만남의광장)    달래네고개  상행  2716
# 156618  20220131  월   경부고속도로  2040002902  경부고속도로(만남의광장)    달래네고개  상행  2716
#
# ...

# %%
df_nonNaN = df.dropna(axis=0)

df_nonNaN
# Out:
#               일자 요일      도로명       링크아이디          시점명      종점명  방향    거리  차선수  \
# 0       20220128  금      을지로  1010011500  동대문역사문화공원입구    한양공고앞  상행   152  3.0
# 1       20220106  목  가산디지털1로  1170004100     한국산업기술협회   금천고가차도  상행   392  2.0
# 2       20220127  목  가산디지털1로  1170004100     한국산업기술협회   금천고가차도  상행   392  2.0
# 3       20220125  화  가산디지털1로  1170004100     한국산업기술협회   금천고가차도  상행   392  2.0
# 4       20220121  금      안암로  1070003400        안암오거리   고대앞사거리  상행   507  2.0
# ...          ... ..      ...         ...          ...      ...  ..   ...  ...
# 156559  20220130  일    강남순환로  1219920030      서초터널중간부  서초터널출구부  하행  1437  3.0
# 156560  20220131  월    강남순환로  1219910090      서초터널입구부  서초터널중간부  상행  1567  3.0
# 156561  20220123  일    강남순환로  1219910090      서초터널입구부  서초터널중간부  상행  1567  3.0
# 156562  20220131  월    강남순환로  1219920030      서초터널중간부  서초터널출구부  하행  1437  3.0
# 156563  20220131  월    강남순환로  1219920020        선암영업소  서초터널중간부  하행  1660  3.0
#
# ...

# %%
dfhead_peakavg = df.head(1000)



def findfreq(frame) :
    frame = frame[['도로명']]
    freq = frame.value_counts(subset="도로명",ascending=False)

    
    return freq


print(findfreq(dfhead_peakavg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\GitRepo\Ongoing-Project\22-1R KU Senior project\220317.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/GitRepo/Ongoing-Project/22-1R%20KU%20Senior%20project/220317.ipynb#ch0000004?line=0'>1</a> dfhead_peakavg = df.head(1000)
#       <a href='vscode-notebook-cell:/c%3A/GitRepo/Ongoing-Project/22-1R%20KU%20Senior%20project/220317.ipynb#ch0000004?line=4'>5</a> def findfreq(frame) :
#       <a href='vscode-notebook-cell:/c%3A/GitRepo/Ongoing-Project/22-1R%20KU%20Senior%20project/220317.ipynb#ch0000004?line=5'>6</a>     frame = frame[['도로명']]
#
# NameError: name 'df' is not defined
